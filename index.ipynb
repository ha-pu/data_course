# %% [markdown]
# # Course Contents
#
# + [2-statistics.ipynb]('../edit/2-statistics.ipynb'): Covers foundational statistical concepts with real-world examples.
# + [3-regressions.ipynb]('../edit/3-regressions.ipynb'): A comprehensive dive into regression analysis, including multiple regression models.
# + [4-machine_learning.ipynb]('../edit/4-machine_learning.ipynb'): Introduces essential machine learning concepts and their practical applications.
# + [5-llms.ipynb]('../edit/5-llms.ipynb'): An exploration of Large Language Models (LLMs) with current insights and examples.

# %% [markdown]
# Welcome to the Data Course! These notebooks provide a guided tour through the core concepts that underpin modern data analytics and machine learning.
#
# ### How to navigate
# 1. Start with the foundational statistics material to build intuition about the data.
# 2. Continue with regression techniques to connect predictors and outcomes.
# 3. Explore machine-learning workflows for scalable modelling.
# 4. Finish with the LLM notebook to experiment with generative AI tooling.
#
# ### Helpful reminders
# - You can run each cell sequentially to reproduce the full analysis.
# - Use the table of contents in JupyterLab to jump between sections quickly.
# - Keep notes on your observations; the reflection prompts in each notebook are designed to spark deeper discussion.
#
# ### Direct links
# - [Basic Statistics](./2-statistics.ipynb)
# - [Regression Analysis](./3-regressions.ipynb)
# - [Machine Learning](./4-machine_learning.ipynb)
# - [Large Language Models](./5-llms.ipynb)
